# %%
import os
import cv2
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# --- Configuration ---
DATASET_DIR = 'dataset'
IMG_SIZE = (100, 100)
# --- End Configuration ---

def load_data():
    """
    Loads all pre-cropped images from the 'dataset' folder.
    """
    print("Loading image data from dataset...")
    data = []
    labels = []
   
    for person_name in os.listdir(DATASET_DIR):
        person_dir = os.path.join(DATASET_DIR, person_name)
        if not os.path.isdir(person_dir):
            continue
           
        for img_file in os.listdir(person_dir):
            img_path = os.path.join(person_dir, img_file)
           
            try:
                # --- NEW: Load image in COLOR ---
                img = cv2.imread(img_path, cv2.IMREAD_COLOR)
               
                if img is None:
                    print(f"Warning: Could not read image {img_path}. Skipping.")
                    continue
               
                if img.shape[0:2] != IMG_SIZE:
                    img = cv2.resize(img, IMG_SIZE)
                   
                data.append(img)
                labels.append(person_name)
               
            except Exception as e:
                print(f"Error loading image {img_path}: {e}")

    print(f"Loaded {len(data)} images.")
    if len(data) == 0:
        print("Error: No data loaded. Is the 'dataset' folder empty?")
        exit()

    # --- Preprocessing ---
   
    # 1. Convert lists to NumPy arrays
    data = np.array(data)
    labels = np.array(labels)

    # 2. --- NEW: Normalize pixel values (from 0-255 to 0.0-1.0) ---
    # This is the standard normalization for custom CNNs
    data = data.astype('float32') / 255.0
   
    # 3. Encode text labels (e.g., "Priya") into numbers (e.g., 0)
    le = LabelEncoder()
    labels_encoded = le.fit_transform(labels)
   
    # 4. One-Hot Encode the number labels
    num_classes = len(np.unique(labels_encoded))
    labels_one_hot = to_categorical(labels_encoded, num_classes=num_classes)
   
    # 5. Save the label encoder classes (the names)
    np.save('labels.npy', le.classes_)
    print(f"Saved label mapping (e.g., 0={le.classes_[0]}): labels.npy")
   
    # 6. Split data into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(
        data, labels_one_hot, test_size=0.2, random_state=42, stratify=labels_one_hot
    )
   
    print(f"Training data shape: {X_train.shape}")
    print(f"Testing data shape: {X_test.shape}")
   
    return X_train, X_test, y_train, y_test, num_classes

def build_custom_cnn(num_classes):
    """
    Builds a more powerful custom CNN model.
    """
    model = Sequential()
   
    # Input layer - now expects (100, 100, 3) for color images
    model.add(Input(shape=(IMG_SIZE[0], IMG_SIZE[1], 3)))

    # --- Block 1 ---
    model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
    model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    # --- Block 2 ---
    model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
    model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    # --- Block 3 ---
    model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
    model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    # --- Classifier Head ---
    model.add(Flatten())
   
    model.add(Dense(256, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
   
    model.add(Dense(128, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
   
    # --- Output Layer ---
    model.add(Dense(num_classes, activation='softmax'))

    model.summary()
    return model

# --- Main Training Script ---

# 1. Load and preprocess the data
X_train, X_test, y_train, y_test, num_classes = load_data()

if num_classes < 2:
    print("Error: Need at least 2 different people in the 'dataset' folder to train.")
    exit()

# 2. Build the new custom model
model = build_custom_cnn(num_classes)

# 3. Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# 4. --- NEW: Set up Data Augmentation ---
datagen = ImageDataGenerator(
    rotation_range=20,     # Randomly rotate images
    zoom_range=0.15,       # Randomly zoom in
    width_shift_range=0.2, # Randomly shift horizontally
    height_shift_range=0.2,# Randomly shift vertically
    shear_range=0.15,      # Shear transformations
    horizontal_flip=True,  # Randomly flip horizontally
    fill_mode="nearest"
)

# 5. Train the model
print("\n--- Starting Model Training ---")
# Increase epochs because augmentation makes the task harder
epochs = 75
batch_size = 32 # We have very few base images, so a small batch size is good

# Use datagen.flow() to feed augmented images
history = model.fit(
    datagen.flow(X_train, y_train, batch_size=batch_size),
    steps_per_epoch=len(X_train) // batch_size if len(X_train) > batch_size else 1,
    epochs=epochs,
    validation_data=(X_test, y_test)
)
print("--- Training Finished ---")

# 6. Evaluate the model on the test set
loss, accuracy = model.evaluate(X_test, y_test)
print(f"\nTest Accuracy: {accuracy * 100:.2f}%")

# 7. Save the trained model
model.save('face_model_cnn.keras')
print("Trained model saved as: face_model_cnn.keras")
# Out:
# Loading image data from dataset...
# Loaded 264 images.
# Saved label mapping (e.g., 0=Navraj): labels.npy
# Training data shape: (211, 100, 100, 3)
# Testing data shape: (53, 100, 100, 3)
# Model: "sequential_11"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_57 (Conv2D)              │ (None, 100, 100, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_58 (Conv2D)              │ (None, 100, 100, 32)   │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_52          │ (None, 100, 100, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_33 (MaxPooling2D) │ (None, 50, 50, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_43 (Dropout)            │ (None, 50, 50, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_59 (Conv2D)              │ (None, 50, 50, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_60 (Conv2D)              │ (None, 50, 50, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_53          │ (None, 50, 50, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_34 (MaxPooling2D) │ (None, 25, 25, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_44 (Dropout)            │ (None, 25, 25, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_61 (Conv2D)              │ (None, 25, 25, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_62 (Conv2D)              │ (None, 25, 25, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_54          │ (None, 25, 25, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_35 (MaxPooling2D) │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_45 (Dropout)            │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_11 (Flatten)            │ (None, 18432)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_30 (Dense)                │ (None, 256)            │     4,718,848 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_55          │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_46 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_31 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_56          │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_47 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_32 (Dense)                │ (None, 44)             │         5,676 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,046,860 (19.25 MB)
#  Trainable params: 5,045,644 (19.25 MB)
#  Non-trainable params: 1,216 (4.75 KB)
# --- Starting Model Training ---
# c:\Users\admin\anaconda3\envs\prlenv\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 795ms/step - accuracy: 0.0056 - loss: 5.0481 - val_accuracy: 0.0377 - val_loss: 3.7865
# Epoch 2/75
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 3s 609ms/step - accuracy: 0.0000e+00 - loss: 5.1723
# c:\Users\admin\anaconda3\envs\prlenv\lib\site-packages\keras\src\trainers\epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - accuracy: 0.0000e+00 - loss: 5.1723 - val_accuracy: 0.0377 - val_loss: 3.7915
# Epoch 3/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 693ms/step - accuracy: 0.0447 - loss: 4.4379 - val_accuracy: 0.0189 - val_loss: 3.8379
# Epoch 4/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.0312 - loss: 4.5304 - val_accuracy: 0.0189 - val_loss: 3.8713
# Epoch 5/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 659ms/step - accuracy: 0.0726 - loss: 4.1404 - val_accuracy: 0.0189 - val_loss: 4.1581
# Epoch 6/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.0312 - loss: 4.1846 - val_accuracy: 0.0000e+00 - val_loss: 4.1948
# Epoch 7/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 649ms/step - accuracy: 0.0838 - loss: 3.8918 - val_accuracy: 0.0000e+00 - val_loss: 4.3478
# Epoch 8/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.0625 - loss: 4.0226 - val_accuracy: 0.0000e+00 - val_loss: 4.3393
# Epoch 9/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 673ms/step - accuracy: 0.0447 - loss: 3.9858 - val_accuracy: 0.0000e+00 - val_loss: 4.5756
# Epoch 10/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.0312 - loss: 4.1448 - val_accuracy: 0.0189 - val_loss: 4.6472
# Epoch 11/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 728ms/step - accuracy: 0.0729 - loss: 3.8438 - val_accuracy: 0.0189 - val_loss: 4.8854
# Epoch 12/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.0526 - loss: 3.8929 - val_accuracy: 0.0189 - val_loss: 4.8681
# Epoch 13/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 662ms/step - accuracy: 0.1229 - loss: 3.6537 - val_accuracy: 0.0189 - val_loss: 4.8747
# Epoch 14/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.0938 - loss: 3.6151 - val_accuracy: 0.0189 - val_loss: 4.9248
# Epoch 15/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 662ms/step - accuracy: 0.0894 - loss: 3.6837 - val_accuracy: 0.0189 - val_loss: 5.6976
# Epoch 16/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.1562 - loss: 3.7060 - val_accuracy: 0.0189 - val_loss: 5.9094
# Epoch 17/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 678ms/step - accuracy: 0.1667 - loss: 3.4293 - val_accuracy: 0.0189 - val_loss: 6.8643
# Epoch 18/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.2105 - loss: 3.5618 - val_accuracy: 0.0189 - val_loss: 7.0677
# Epoch 19/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 629ms/step - accuracy: 0.1341 - loss: 3.2319 - val_accuracy: 0.0189 - val_loss: 8.0179
# Epoch 20/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.1250 - loss: 3.1743 - val_accuracy: 0.0189 - val_loss: 8.2188
# Epoch 21/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 673ms/step - accuracy: 0.0990 - loss: 3.3830 - val_accuracy: 0.0189 - val_loss: 8.9923
# Epoch 22/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.2105 - loss: 3.3890 - val_accuracy: 0.0189 - val_loss: 9.1403
# Epoch 23/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 677ms/step - accuracy: 0.2292 - loss: 3.0603 - val_accuracy: 0.0189 - val_loss: 9.3127
# Epoch 24/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.2632 - loss: 2.9646 - val_accuracy: 0.0189 - val_loss: 9.2949
# Epoch 25/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 669ms/step - accuracy: 0.2135 - loss: 2.8954 - val_accuracy: 0.0189 - val_loss: 9.1474
# Epoch 26/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.1579 - loss: 3.6710 - val_accuracy: 0.0189 - val_loss: 9.0924
# Epoch 27/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 689ms/step - accuracy: 0.2346 - loss: 2.9186 - val_accuracy: 0.0189 - val_loss: 8.6624
# Epoch 28/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.2500 - loss: 3.1400 - val_accuracy: 0.0189 - val_loss: 8.6309
# Epoch 29/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 638ms/step - accuracy: 0.2402 - loss: 2.7567 - val_accuracy: 0.0189 - val_loss: 8.5732
# Epoch 30/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.1562 - loss: 2.8843 - val_accuracy: 0.0189 - val_loss: 8.6026
# Epoch 31/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 620ms/step - accuracy: 0.1955 - loss: 2.9028 - val_accuracy: 0.0189 - val_loss: 8.7283
# Epoch 32/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.2500 - loss: 2.5069 - val_accuracy: 0.0189 - val_loss: 8.7742
# Epoch 33/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 622ms/step - accuracy: 0.1844 - loss: 2.6926 - val_accuracy: 0.0377 - val_loss: 8.8604
# Epoch 34/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.1562 - loss: 2.7099 - val_accuracy: 0.0566 - val_loss: 8.9274
# Epoch 35/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 615ms/step - accuracy: 0.2793 - loss: 2.5726 - val_accuracy: 0.0377 - val_loss: 9.2852
# Epoch 36/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.2500 - loss: 2.7703 - val_accuracy: 0.0377 - val_loss: 9.3336
# Epoch 37/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 648ms/step - accuracy: 0.3296 - loss: 2.5905 - val_accuracy: 0.0566 - val_loss: 9.5496
# Epoch 38/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.3438 - loss: 2.3724 - val_accuracy: 0.0377 - val_loss: 9.6281
# Epoch 39/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 629ms/step - accuracy: 0.2793 - loss: 2.4807 - val_accuracy: 0.0189 - val_loss: 10.2536
# Epoch 40/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.1562 - loss: 2.9167 - val_accuracy: 0.0189 - val_loss: 10.4203
# Epoch 41/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 618ms/step - accuracy: 0.2179 - loss: 2.7728 - val_accuracy: 0.0189 - val_loss: 11.1575
# Epoch 42/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.2812 - loss: 2.5041 - val_accuracy: 0.0189 - val_loss: 11.1914
# Epoch 43/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 621ms/step - accuracy: 0.3631 - loss: 2.2294 - val_accuracy: 0.0189 - val_loss: 11.3208
# Epoch 44/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.3438 - loss: 2.0881 - val_accuracy: 0.0189 - val_loss: 11.4278
# Epoch 45/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 670ms/step - accuracy: 0.2570 - loss: 2.4362 - val_accuracy: 0.0189 - val_loss: 11.6411
# Epoch 46/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.3125 - loss: 2.2386 - val_accuracy: 0.0189 - val_loss: 11.7021
# Epoch 47/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 644ms/step - accuracy: 0.3240 - loss: 2.3284 - val_accuracy: 0.0189 - val_loss: 11.9954
# Epoch 48/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.4688 - loss: 2.0164 - val_accuracy: 0.0189 - val_loss: 12.0589
# Epoch 49/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 630ms/step - accuracy: 0.3408 - loss: 2.1642 - val_accuracy: 0.0189 - val_loss: 12.3964
# Epoch 50/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.3125 - loss: 2.4841 - val_accuracy: 0.0189 - val_loss: 12.3729
# Epoch 51/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 644ms/step - accuracy: 0.3128 - loss: 2.3839 - val_accuracy: 0.0189 - val_loss: 12.3025
# Epoch 52/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.4062 - loss: 2.2142 - val_accuracy: 0.0189 - val_loss: 12.2087
# Epoch 53/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 669ms/step - accuracy: 0.3520 - loss: 2.3017 - val_accuracy: 0.0566 - val_loss: 11.8643
# Epoch 54/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.2188 - loss: 2.5626 - val_accuracy: 0.0566 - val_loss: 11.9496
# Epoch 55/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 683ms/step - accuracy: 0.3575 - loss: 2.2580 - val_accuracy: 0.0189 - val_loss: 12.4188
# Epoch 56/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.3438 - loss: 1.9440 - val_accuracy: 0.0189 - val_loss: 12.3914
# Epoch 57/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 708ms/step - accuracy: 0.4022 - loss: 2.0891 - val_accuracy: 0.0377 - val_loss: 12.0744
# Epoch 58/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.3438 - loss: 2.5782 - val_accuracy: 0.0377 - val_loss: 12.0139
# Epoch 59/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 640ms/step - accuracy: 0.3575 - loss: 2.2148 - val_accuracy: 0.0189 - val_loss: 11.8176
# Epoch 60/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.4062 - loss: 2.1162 - val_accuracy: 0.0189 - val_loss: 11.7626
# Epoch 61/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 624ms/step - accuracy: 0.4022 - loss: 1.9681 - val_accuracy: 0.0189 - val_loss: 11.9007
# Epoch 62/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.3438 - loss: 2.3342 - val_accuracy: 0.0189 - val_loss: 11.9243
# Epoch 63/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 683ms/step - accuracy: 0.3911 - loss: 2.0344 - val_accuracy: 0.0189 - val_loss: 11.4009
# Epoch 64/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.4375 - loss: 2.0039 - val_accuracy: 0.0189 - val_loss: 11.3055
# Epoch 65/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 671ms/step - accuracy: 0.4525 - loss: 1.9021 - val_accuracy: 0.0189 - val_loss: 11.0202
# Epoch 66/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.3750 - loss: 1.9328 - val_accuracy: 0.0189 - val_loss: 11.0417
# Epoch 67/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 630ms/step - accuracy: 0.3408 - loss: 2.0558 - val_accuracy: 0.0189 - val_loss: 11.2536
# Epoch 68/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.5312 - loss: 1.5817 - val_accuracy: 0.0189 - val_loss: 11.3561
# Epoch 69/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 620ms/step - accuracy: 0.4916 - loss: 1.8142 - val_accuracy: 0.0189 - val_loss: 11.4308
# Epoch 70/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.3125 - loss: 2.1003 - val_accuracy: 0.0189 - val_loss: 11.3317
# Epoch 71/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 680ms/step - accuracy: 0.4219 - loss: 1.8714 - val_accuracy: 0.0189 - val_loss: 11.0605
# Epoch 72/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.3684 - loss: 1.9746 - val_accuracy: 0.0189 - val_loss: 11.0396
# Epoch 73/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 616ms/step - accuracy: 0.4637 - loss: 1.8566 - val_accuracy: 0.0189 - val_loss: 10.8784
# Epoch 74/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.5312 - loss: 1.6439 - val_accuracy: 0.0189 - val_loss: 10.7980
# Epoch 75/75
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 633ms/step - accuracy: 0.3687 - loss: 1.8456 - val_accuracy: 0.0189 - val_loss: 10.8883
# --- Training Finished ---
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.0189 - loss: 10.8883
#
# Test Accuracy: 1.89%
# Trained model saved as: face_model_cnn.keras
